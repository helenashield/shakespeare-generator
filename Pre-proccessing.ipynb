# %%
# Convert syllable dictionary to dictionary
# Data will be saved as word: [syllables]
syll = {}
f = open("data/Syllable_dictionary.txt", 'r')
for line in f.readlines():
    newline = line.split(' ', 1)
    print(newline)
    key = newline[0]
    value = newline[1]
    if value == value.split(' ')[0]: # if there is only one value
        syllables = int(value)
    else:
        syllables = []
        for v in value.split(' '):
            if 'E' in v:
                syllables.append()
# Out:
# ["'gainst", '1\n']
# ["'greeing", 'E1 2\n']
# ["'scaped", '1\n']
# ["'tis", '1\n']
# ["'twixt", '1\n']
# ['a', '1\n']
# ['a-doting', 'E2 3\n']
# ['abhor', '2\n']
# ['abide', '2\n']
# ['able', '2\n']
# ['about', '2\n']
# ['above', '2\n']
# ['absence', '2\n']
# ['absent', '2\n']
# ['abundance', '3\n']
# ['abundant', '3\n']
# ['abuse', '2\n']
# ['abused', '2\n']
# ['abuses', '3\n']
# ['abysm', '2\n']
# ['accents', '2\n']
# ['acceptable', '4\n']
# ['acceptance', '3\n']
# ['accessary', '4\n']
# ['accident', '3\n']
# ['accidents', '3\n']
# ['account', '2\n']
# ['accumulate', '4\n']
# ['accuse', '2\n']
# ['accusing', '3\n']
# ['achieve', '2\n']
# ['acknowledge', '3\n']
# ['acquaintance', '3\n']
# ['acquainted', 'E2 3\n']
# ['act', '1\n']
# ['action', '2\n']
# ['active', '2\n']
# ['actor', '2\n']
# ['add', '1\n']
# ['added', '2\n']
# ["adder's", '2\n']
# ['addeth', '2\n']
# ['adding', '2\n']
# ['addition', '3\n']
# ['adieu', '2\n']
# ['adjunct', '2\n']
# ['admire', '2\n']
# ...

# %%
a = 'E12'
a[1:]
# Out:
# '12'
